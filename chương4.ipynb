# %% [markdown]
# <a href="https://colab.research.google.com/github/hdat1509/ThToancaocap/blob/main/ch%C6%B0%C6%A1ng4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TH 1

# %%
import numpy as np
mienchia=np.linspace(0,2,11)
mienchia
# Out:
# array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ])

# %% [markdown]
# TH 2

# %%
import numpy as np
import matplotlib.pyplot as plt
fs=[1,2,4]
all_time=np.linspace(0,2,200)
t=all_time[:100]
for f in fs:
  y=np.sin(2*np.pi*f*t)
  plt.plot(t,y,label='{}Hz'.format(f))
  plt.legend()
  from google.colab import drive
  drive.mount('/drive')
  plt.savefig('/drive/My Drive/THChuong4/basics_python.pdf')
  plt.show()
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %% [markdown]
# TH 3

# %%
import numpy as np
import matplotlib.pyplot as plt
fs=[1,2,4]
all_time=np.linspace(0,2,200)
t=all_time[:100]
for f in fs:
  y=np.sin(2*np.pi*f*t)
  plt.plot(t,y,label='{}Hz'.format(f))
  plt.legend()
  from google.colab import drive
  drive.mount('/drive')
  plt.savefig('/drive/My Drive/THChuong4/basics_python.pdf')
  plt.show()
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %%
import numpy as np
import matplotlib.pyplot as plt
fs=[1,2,4]
all_time=np.linspace(0,2,200)
t=all_time[:100]
fig, ax=plt.subplots()
for f in fs:
  y=np.sin(2*np.pi*f*t)
  ax.plot(t,y,label='{}Hz'.format(f))
  plt.legend()
  from google.colab import drive
  drive.mount('/drive')
  plt.savefig('/drive/My Drive/THChuong4/basics_python.pdf')
  plt.show()
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).
# No handles with labels found to put in legend.
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).
# No handles with labels found to put in legend.
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %% [markdown]
# TH 4

# %%
def f (x): return x**2
print(f(8))
# Out:
# 64

# %%
g = lambda x : x**2
print(g(8))
# Out:
# 64

# %% [markdown]
# TH 5

# %%
def thue(phantram):return lambda x:x*phantram
hcm=thue(0.012)
hn=thue(0.01)

# %%
hcm(1000000)
# Out:
# 12000.0

# %%
hn(1000000)
# Out:
# 10000.0

# %% [markdown]
# TH 6

# %%
hinhthan=lambda f,a,b:(b-a)*(f(a)+f(b))/2
from math import exp
hinhthan(exp,0,1)
# Out:
# 1.8591409142295225

# %%
def hai_x(x):
  return 2*x

# %%
hinhthan(hai_x,1,2)
# Out:
# 3.0

# %% [markdown]
# TH 7

# %% [markdown]
# Hàm tính theo luật hình thang cho hàm(x) từ (trái, phải)
